# %%
import json
import numpy as np
import pandas as pd
from nltk.metrics import edit_distance
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, average_precision_score, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# %%
#Load Dataset
locu_train = pd.read_json('locu_train.json')
four_train = pd.read_json('foursquare_train.json')
match_train = pd.read_csv('matches_train.csv')
locu_test = pd.read_json('locu_test.json')
four_test = pd.read_json('foursquare_test.json')

# %%
locu_test
# Out:
#            country                    id   latitude  locality  longitude  \
# 0    United States  b48da849c54f904013e2  40.758005  New York -73.992727
# 1    United States  95ad783fd1c65bb8fdbf  40.721025  New York -73.982903
# 2    United States  5060d123ccad77923b20  40.725772  New York -73.991947
# 3    United States  9dd6f6b177096efd5da4  40.802047  New York -73.936988
# 4    United States  4773c30d2df4368c0d09  40.725190  New York -73.992547
# 5    United States  206c363a5907bfa98ec0  40.737576  New York -73.996471
# 6    United States  cb95d1e0730222cc3209  40.760685  New York -73.982570
# 7    United States  ecdc736a7d663a46e01d  40.768370  New York -73.984916
# 8    United States  25ca87e725b930488ed6  40.755325  New York -73.990906
# 9    United States  4f9710321455164d1cb4  40.742367  New York -74.003204
# 10   United States  daff4926a1d14a6c2921  40.765683  New York -73.976401
# 11   United States  138aed748ccdfed0845d  40.803884  New York -73.955875
# 12   United States  6a80339865339c7d4e52  43.096596  New York -76.381458
# 13   United States  a16c8ddbcf2ea4d3ccad  40.754922  New York -73.989909
# 14   United States  5013d96a9633f92f2dbf  40.751522  New York -73.980221
# 15   United States  b2affc7b53499fd8ee76  40.761488  New York -73.960607
# 16   United States  8c793887992c0f78bd27  40.708277  New York -74.005160
# 17   United States  8f922b60da3c4795c589  40.660550  New York -73.960699
# 18   United States  7b11cde179779d2e814d  40.723321  New York -73.982386
# 19   United States  1ff1b1c1d5252ca3682a  40.748853  New York -73.992386
# 20   United States  f9f61ba2a57897a84b70  43.262831  New York -78.193128
# 21   United States  96bd550c35ac34818c9a  40.717192  New York -73.994777
# 22   United States  417df85b1156d93935b3  40.753931  New York -73.989652
# 23   United States  be74338f204c673792a9  40.722543  New York -73.988607
# 24   United States  76b75b0a67c0bcd6682f  40.749101  New York -73.992006
# 25   United States  0b349f0d5401a0e1d58e  40.751516  New York -73.981590
# 26   United States  d837156a7175ece3df6e  40.826815  New York -73.946587
# 27   United States  10d0e40eca8098beb6fa  40.761512  New York -73.984260
# 28   United States  b1e54c079d60ec3745bd  40.742942  New York -73.982076
# 29   United States  86421a8058103fd73842  40.764170  New York -73.984734
# ..             ...                   ...        ...       ...        ...
# 370  United States  01fbb407f1d35118f8b9  40.714987  New York -73.998626
# 371  United States  187cd0a57c8a73cfdad4  40.740576  New York -73.990929
# 372  United States  6143d53e474b953ae451  40.775142  New York -73.956644
# 373  United States  cf2103efafd411e5cd36  40.791065  New York -73.945159
# 374  United States  4d99d389aed56c5763e9  40.785288  New York -73.955648
# 375  United States  7fd1b10aef85e621126f  40.734296  New York -74.007162
# 376  United States  f1a683f11d1243992f35  40.704988  New York -74.009785
# 377  United States  eb93ad97c8126af3f133  40.727128  New York -73.989992
# 378  United States  a7e4e7ac45e5723f3541  40.740300  New York -74.005598
# 379  United States  22aeefab5f873825cabd  40.740596  New York -73.989339
# 380  United States  cc43da1b93604d959e67  40.800325  New York -73.965807
# 381  United States  d298e3887009b084fa29  40.705770  New York -73.931839
# 382  United States  4bd7246a7526012bf2df  40.857977  New York -73.930904
# 383  United States  6587c72487e49cd165e0  40.749539  New York -73.977435
# 384  United States  8bb064a614c4866beaea  40.751879  New York -73.974106
# 385  United States  d9537beb66f9f2aac1ad  40.751479  New York -73.987908
# 386  United States  0596be1ee8194c628f4e  40.714974  New York -74.008046
# 387  United States  a53a15c0b0d206b0075a  40.800856  New York -73.944161
# 388  United States  d258ff5f83e58d411e6f  40.740704  New York -73.991469
# 389  United States  c7b6eb8be8d8fb8e98c6  40.720101  New York -73.995603
# 390  United States  c5d0d177ae0631a4d60f  40.805386  New York -73.949093
# 391  United States  45924c61a6e76401a34f  40.829216  New York -73.948375
# 392  United States  85c01bb5c538231cd2c5  40.769502  New York -73.960555
# 393  United States  5d0f19bd69a424c63102  40.747641  New York -73.993250
# 394  United States  98213a8b5b76e161b1dd  40.761770  New York -73.981908
# 395  United States  74d422d2aacd0ab2223a  40.704249  New York -74.011569
# 396  United States  e34c98f447b1b7dc1d1e  40.756257  New York -73.985233
# 397  United States  278dd7a1fa00e9187aa4  40.855324  New York -73.937240
# 398  United States  474f8fbac38b1114439a  40.749905  New York -73.977043
# 399  United States  3130f6fd989210a73c9a  40.758918  New York -73.988773
#
#                                         name       phone postal_code region  \
# 0                           Panda Restaurant  2126950836       10036     NY
# 1                        El Maguey y la Tuna  2124733919       10002     NY
# 2    Hair Date Salon/ Professionals Hair Cut  2122288381       10003     NY
# 3                             Pizza Plus Inc  2122890005       10035     NY
# 4                               Double Crown  2122540350       10012     NY
# 5                               Pink Tea Cup  2122060605       10011     NY
# 6                             Roses Mexicano                   10022     NY
# 7                 Hudson Common @ the Hudson  2125546217       10019     NY
# 8                                  Starbucks  2129977341       10018     NY
# 9                     ..nyc jaajjjj......:-D                   10011     NY
# 10                 Trump's World Tower Valet  2127591068       10019     NY
# 11                      283 W 115th St Corp.  2128651910       10026     NY
# 12                           Time Warner Inc  2124848000       10019     NY
# 13                         Bernstein Textile  2123545213       10018     NY
# 14           Hopkins Foodservice Specialists  2126799293                 NY
# 15                       Dalga Seafood Grill  2128131790       10065     NY
# 16                     Iron Horse Restaurant  6464484471       10038     NY
# 17                      Jaquira Beauty Salon  7184624281       11225     NY
# 18                           The Best Bodega                             NY
# 19                  Harrington's Bar & Grill  2127363636       10001     NY
# 20                  Lin Min Zhang Restaurant  7189978000       11375     NY
# 21                     Lai Fan Beauty Center  2122191383       10002     NY
# 22                     Tagine Dining Gallery                   10018     NY
# 23                BRBG at the Thompson Hotel  2124605300       10002     NY
# 24                     Gold Group of Atlanta  2125947817                 NY
# 25                        40 st coffee stand                   10016     NY
# 26                               Naty Unisex                   10031     NY
# 27                          Harmony View Bar  2129575100       10019     NY
# 28                             Whiskey Rebel  2126863800       10016     NY
# 29                         Avanti Nail & Spa  2127571269       10019     NY
# ..                                       ...         ...         ...    ...
# 370                   ABC Chinese Restaurant  2123469390       10013     NY
# 371          Four Star General Cleaning Corp  2127419400       10010     NY
# 372              Taste Restaurant & Wine Bar  2127179798       10028     NY
# 373                 Venus Beauty Corporation  2123692836       10029     NY
# 374                                 Le Paris  2122890997       10128     NY
# 375                              Lotus Salon  2124621050       10014     NY
# 376                                 Yorganic  2129689700       10004     NY
# 377                         Hair In the City  2122285009       10003     NY
# 378                      Bill's Bar & Burger  2124143003       10014     NY
# 379                             Salon Canova  2124735593       10010     NY
# 380                     Chung Wah Restaurant  2128647997       10025     NY
# 381                            Shinobi Ramen                   11237     NY
# 382                Centro De Belleza Albania  2129425908       10034     NY
# 383                  Murray Hill Dry Cleaner  2126826855       10016     NY
# 384              Five Guys Burgers and Fries  6467835060       10017     NY
# 385                             Wink Eyelash  2125949465       10018     NY
# 386             Dale Earnhardt Jr Jr's House                             NY
# 387                          Oxford Cleaners  2128766638       10035     NY
# 388      Barbering By Marcus (@Alma G Salon)  6463272929       10010     NY
# 389                 Zusel's French Bread Co.                   10012     NY
# 390                       Lavette Hair Salon  2126652487       10027     NY
# 391                       Tonalli Café & Bar  2129260399       10031     NY
# 392                                THE Couch                   10021     NY
# 393               The Triple Crown Ale House  2127361575       10001     NY
# 394  Venti Black Tea Lemonade 4 Pump Classic                   10019     NY
# 395             Quiznos Sandwich Restaurants  2127857827       10004     NY
# 396                          Brooklyn Hummus                   10036     NY
# 397                          Next Door - NYC  2125432111       10033     NY
# 398                            Bagel Express                   10016     NY
# 399                         Church's Chicken  2123159600       10036     NY
#
#                     street_address  \
# 0                     570 9th Ave.
# 1             321 East Houston St.
# 2                       329 Bowery
# 3                2253 3rd Ave. # 1
# 4                       316 Bowery
# 5                     538 6th Ave.
# 6                         1st Ave.
# 7                  356 W. 58th St.
# 8                  600 Eighth Ave.
# 9
# 10          106 Central Park South
# 11                283 W. 115th St.
# 12               1 Time Warner Ctr
# 13            270 W. 39th St. # 20
# 14                280 Madison Ave.
# 15                 401 E. 62nd St.
# 16                    32 Cliff St.
# 17               544 Flatbush Ave.
# 18
# 19                    370 7th Ave.
# 20              10119 Queens Blvd.
# 21                  143 Hester St.
# 22                 221 W. 38th St.
# 23                   190 Allen St.
# 24                     1 Penn Plz.
# 25                    60 Worth St.
# 26         1766 Amsterdam Ave. # 1
# 27                 210 W. 50th St.
# 28              129 Lexington Ave.
# 29                888 8th Ave. # 6
# ..                             ...
# 370                    34 Pell St.
# 371               19 West 21st St.
# 372                1413 Third Ave.
# 373           1906 3rd Ave. # 1056
# 374              1312 Madison Ave.
# 375              718 Greenwich St.
# 376               3 Hanover Square
# 377               219 East 5th St.
# 378                    22 9th Ave.
# 379                   942 Broadway
# 380       935 Amsterdam Ave. # 106
# 381                 53 Morgan Ave.
# 382            4876 Broadway # 204
# 383              129 East 39th St.
# 384                   690 3rd Ave.
# 385              128 West 36th St.
# 386
# 387              1791 Madison Ave.
# 388               38 East 21st St.
# 389                 362 Broome St.
# 390             161 West 120th St.
# 391                  3628 Broadway
# 392
# 393                   330 7th Ave.
# 394
# 395                   80 Broad St.
# 396                  Moving Target
# 397  811 West 187<sup>th</sup> St.
# 398             349 Lexington Ave.
# 399                   705 8th Ave.
#
#                                                website
# 0                                  http://pandarg.com/
# 1                    http://www.elmagueyylatunamex.com
# 2                          http://www.hairdatenyc.com/
# 3                        http://www.pizzaplusmore.com/
# 4                           http://doublecrown-nyc.com
# 5                      http://www.thinkpinkteacup.com/
# 6
# 7                  http://www.hudsonhotel.com/#/explor
# 8                            http://www.starbucks.com/
# 9
# 10
# 11
# 12                          http://www.timewarner.com/
# 13                  http://www.berensteintextiles.com/
# 14
# 15
# 16                         http://www.ironhorsenyc.com
# 17
# 18
# 19                      http://www.harringtonsbar.com/
# 20
# 21
# 22
# 23   http://www.thompsonhotels.com/hotels/nyc/thomp...
# 24
# 25
# 26
# 27
# 28                         http://whiskeyrebelnyc.com/
# 29                   http://www.avantinailsandspa.com/
# ..                                                 ...
# 370
# 371                          http://4starcleaning.com/
# 372                            http://www.elizabar.com
# 373
# 374                     http://www.leparisbistrot.com/
# 375    http://www.lotussalonny.com/html/greenwich.html
# 376                            http://yorganicnyc.com/
# 377
# 378                  http://www.billsbarandburger.com/
# 379
# 380
# 381                 http://shinobinoodle.blogspot.com/
# 382
# 383
# 384                           http://www.fiveguys.com/
# 385                        http://www.winkeyelash.com/
# 386
# 387
# 388                  http://www.barberingbymarcus.com/
# 389
# 390
# 391
# 392
# 393                         http://triplecrownnyc.com/
# 394
# 395   http://www.quiznos.com/restaurants/NY/New%20York
# 396
# 397                             http://www.107west.com
# 398
# 399                            http://www.churchs.com/
#
# [400 rows x 11 columns]

# %% [markdown]
# ### 1. Observe datasets

# %%
locu_train.shape, four_train.shape
# Out:
# ((600, 11), (600, 11))

# %%
locu_test.shape, four_test.shape
# Out:
# ((400, 11), (400, 11))

# %%
locu_train.head()
# Out:
#          country                    id   latitude  locality  longitude  \
# 0  United States  cc9e8f40230c6ead2873  40.739822  New York -73.985144
# 1  United States  81df045e563fb6cab7f7  40.810765  New York -73.952591
# 2  United States  b265cf6c80121211dbfc  40.743580  New York -73.986127
# 3  United States  4fc50abefae5311cc2b3  40.828820  New York -73.949022
# 4  United States  72560dc41f1b7aed0d47  40.749936  New York -73.983849
#
#                       name       phone postal_code region  \
# 0   Chipotle Mexican Grill  2126736904       10010     NY
# 1          Honey Salon Inc  2126630100       10026     NY
# 2                  Palatte  6464763812       10016     NY
# 3    Best Taste Restaurant  2122815691       10031     NY
# 4  Integra Hair System Inc  2125636786       10018     NY
#
#             street_address                      website
# 0        125 East 23rd St.     http://www.chipotle.com/
# 1  174 Saint Nicholas Ave.
# 2          66 Madison Ave.   http://www.palattenyc.com/
# 3            3609 Broadway
# 4       11 W. 36th St. # 3  http://www.integrahair.com/

# %%
four_train.head()
# Out:
#          country                        id   latitude  locality  longitude  \
# 0  United States  4f328ea619836c91c7e3714a  40.794855  New York -73.966069
# 1  United States  4c37b5f6ae2da593a56affc5  40.760460  New York -73.994920
# 2  United States  4b41060df964a52098bf25e3  40.760249  New York -73.983746
# 3  United States  3fd66200f964a520ece41ee3  40.708660  New York -74.011263
# 4  United States  52064aab11d284f64d088329  40.718105  New York -73.996096
#
#                                  name           phone postal_code region  \
# 0            Chen Jin Diao Restaurant  (212) 678-4680                 NY
# 1                West Side Steakhouse  (212) 564-4803       10036     NY
# 2  Pearls: Chinese & Szechuan Cuisine  (212) 582-7380       10019     NY
# 3                          Suspenders  (212) 732-5005       10006     NY
# 4                  Grand Century Cafe            None                 NY
#
#       street_address                       website
# 0  800 Columbus Ave.
# 1      597 10th Ave.
# 2       732 7th Ave.
# 3       111 Broadway  http://www.suspendersnyc.com
# 4

# %%
match_train.head()
# Out:
#                 locu_id             foursquare_id
# 0  1dae3a8f02f730c3528d  4b694c01f964a520139e2be3
# 1  219c994dcc53f891ec26  506b6162e4b02bda7fc846ee
# 2  e06dd73a03f255a877de  4fcb5d2ee4b0928dc1d32f10
# 3  cf429074f6b45f0ad183  4c2d2315e116e21e1b1a8e60
# 4  be428df89cec53c29e96  43ed7e9ef964a5204e2f1fe3

# %%
pd.concat([locu_train.apply(lambda x: sum(x.isnull())).rename("num_missing"),
          locu_train.apply(lambda x: sum(x=="unknown")).rename("num_unkowns"),
          locu_train.apply(lambda x: len(np.unique(x))).rename("num_unique")],axis=1)
# Out:
#                 num_missing  num_unkowns  num_unique
# country                   0            0           1
# id                        0            0         600
# latitude                  1            0         587
# locality                  0            0           1
# longitude                 1            0         584
# name                      0            0         586
# phone                     0            0         498
# postal_code               0            0          68
# region                    0            0           1
# street_address            0            0         561
# website                   0            0         273

# %%
pd.concat([locu_test.apply(lambda x: sum(x.isnull())).rename("num_missing"),
          locu_test.apply(lambda x: sum(x=="unknown")).rename("num_unkowns"),
          locu_test.apply(lambda x: len(np.unique(x))).rename("num_unique")],axis=1)
# Out:
#                 num_missing  num_unkowns  num_unique
# country                   0            0           1
# id                        0            0         400
# latitude                  1            0         395
# locality                  0            0           1
# longitude                 1            0         395
# name                      0            0         392
# phone                     0            0         334
# postal_code               0            0          63
# region                    0            0           1
# street_address            0            0         372
# website                   0            0         188

# %% [markdown]
# ### 2. Data processing

# %%
#Change phone number to the same foramt
locu_train.loc[:, "phone"] = locu_train.phone.str.replace("[^0-9]", "")
four_train.loc[:, "phone"] = four_train.phone.str.replace("[^0-9]", "")

locu_test.loc[:, "phone"] = locu_test.phone.str.replace("[^0-9]", "")
four_test.loc[:, "phone"] = four_test.phone.str.replace("[^0-9]", "")

# %%
#Change name to lowercases
locu_train.loc[:, "name"] = locu_train.name.str.lower()
four_train.loc[:, "name"] = four_train.name.str.lower()

locu_test.loc[:, "name"] = locu_test.name.str.lower()
four_test.loc[:, "name"] = four_test.name.str.lower()

# %%
#Change street_address
locu_train.loc[:, "street_address"] = locu_train.street_address.str.lower()
four_train.loc[:, "street_address"] = four_train.street_address.str.lower()

locu_train.loc[:, "street_address"] = locu_train.street_address.str.replace("w\.", "west ")
four_train.loc[:, "street_address"] = four_train.street_address.str.replace("w\.", "west ")

locu_train.loc[:, "street_address"] = locu_train.street_address.str.replace("e\.", "east ")
four_train.loc[:, "street_address"] = four_train.street_address.str.replace("e\.", "east ")

# %%
locu_test.loc[:, "street_address"] = locu_test.street_address.str.lower()
four_test.loc[:, "street_address"] = four_test.street_address.str.lower()

locu_test.loc[:, "street_address"] = locu_test.street_address.str.replace("w\.", "west ")
four_test.loc[:, "street_address"] = four_test.street_address.str.replace("w\.", "west ")

locu_test.loc[:, "street_address"] = locu_test.street_address.str.replace("e\.", "east ")
four_test.loc[:, "street_address"] = four_test.street_address.str.replace("e\.", "east ")

# %%
#Change website to lower cases
locu_train.loc[:, "website"] = locu_train.website.str.lower()
four_train.loc[:, "website"] = four_train.website.str.lower()

locu_test.loc[:, "website"] = locu_test.website.str.lower()
four_test.loc[:, "website"] = four_test.website.str.lower()

# %% [markdown]
# ### 3. Join datasets and culculate the difference between features

# %%
trainSet = locu_train.merge(four_train, how = "outer", on = ["country", "region", "locality", "postal_code"])
testSet = locu_test.merge(four_test, how = "outer", on = ["country", "region", "locality", "postal_code"])

# %%
#Drop rows with all nan
trainSet = trainSet.dropna(subset=['latitude_x', 'longitude_x', 'name_x', 'street_address_x'], how='all')
trainSet = trainSet.dropna(subset=['latitude_y', 'longitude_y', 'name_y', 'street_address_y'], how='all')

testSet = testSet.dropna(subset=['latitude_x', 'longitude_x', 'name_x', 'street_address_x'], how='all')
testSet = testSet.dropna(subset=['latitude_y', 'longitude_y', 'name_y', 'street_address_y'], how='all')

# %%
trainSet.shape, testSet.shape
# Out:
# ((16027, 18), (6881, 18))

# %%
#Difference between features
trainSet = trainSet.assign(lat_diff = np.abs(trainSet.latitude_x - trainSet.latitude_y))
trainSet = trainSet.assign(long_diff = np.abs(trainSet.longitude_x - trainSet.longitude_y))
trainSet = trainSet.assign(phone_diff = 1*(trainSet.phone_x == trainSet.phone_y))

# %%
testSet = testSet.assign(lat_diff = np.abs(testSet.latitude_x - testSet.latitude_y))
testSet = testSet.assign(long_diff = np.abs(testSet.longitude_x - testSet.longitude_y))
testSet = testSet.assign(phone_diff = 1*(testSet.phone_x == testSet.phone_y))

# %%
#Distance between features in names
trainSet.loc[:, "name_diff"]= trainSet.apply(lambda x: edit_distance(x["name_x"], x["name_y"]), axis=1)

testSet.loc[:, "name_diff"]= testSet.apply(lambda x: edit_distance(x["name_x"], x["name_y"]), axis=1)

# %%
#Distance between features in address
trainSet.loc[:, "address_diff"]= trainSet.apply(lambda x: edit_distance(x["street_address_x"], x["street_address_y"]), axis=1)

testSet.loc[:, "address_diff"]= testSet.apply(lambda x: edit_distance(x["street_address_x"], x["street_address_y"]), axis=1)

# %%
#Distance between features in website
trainSet.loc[:, "web_diff"]= trainSet.apply(lambda x: edit_distance(x["website_x"], x["website_y"]), axis=1)

testSet.loc[:, "web_diff"]= testSet.apply(lambda x: edit_distance(x["website_x"], x["website_y"]), axis=1)

# %%
match_train.head()
# Out:
#                 locu_id             foursquare_id
# 0  1dae3a8f02f730c3528d  4b694c01f964a520139e2be3
# 1  219c994dcc53f891ec26  506b6162e4b02bda7fc846ee
# 2  e06dd73a03f255a877de  4fcb5d2ee4b0928dc1d32f10
# 3  cf429074f6b45f0ad183  4c2d2315e116e21e1b1a8e60
# 4  be428df89cec53c29e96  43ed7e9ef964a5204e2f1fe3

# %% [markdown]
# ### 4. Add label to dataset

# %%
#Rename trainSet
trainSet.columns.values[1] = 'locu_id'
trainSet.columns.values[11] = 'foursquare_id'
trainSet.head()
# Out:
#          country               locu_id  latitude_x  locality  longitude_x  \
# 0  United States  cc9e8f40230c6ead2873   40.739822  New York   -73.985144
# 1  United States  cc9e8f40230c6ead2873   40.739822  New York   -73.985144
# 2  United States  cc9e8f40230c6ead2873   40.739822  New York   -73.985144
# 3  United States  cc9e8f40230c6ead2873   40.739822  New York   -73.985144
# 4  United States  cc9e8f40230c6ead2873   40.739822  New York   -73.985144
#
#                    name_x     phone_x postal_code region   street_address_x  \
# 0  chipotle mexican grill  2126736904       10010     NY  125 east 23rd st.
# 1  chipotle mexican grill  2126736904       10010     NY  125 east 23rd st.
# 2  chipotle mexican grill  2126736904       10010     NY  125 east 23rd st.
# 3  chipotle mexican grill  2126736904       10010     NY  125 east 23rd st.
# 4  chipotle mexican grill  2126736904       10010     NY  125 east 23rd st.
#
#      ...               name_y     phone_y   street_address_y  \
# 0    ...           via emilia  2125053072  47 east  21st st.
# 1    ...     the crepes truck        None   6 east  23rd st.
# 2    ...                  eau  2123588647       913 broadway
# 3    ...         the yard bar        None  55 west  21st st.
# 4    ...          white walls        None
#
#                  website_y  lat_diff long_diff phone_diff name_diff  \
# 0  http://viaemilianyc.net  0.000564  0.002991          0        17
# 1                           0.001128  0.002769          0        17
# 2                           0.000259  0.004682          0        20
# 3                           0.001554  0.008091          0        18
# 4                           0.003752  0.005549          0        15
#
#    address_diff  web_diff
# 0             7        16
# 1             4        24
# 2            15        24
# 3             8        24
# 4            17        24
#
# [5 rows x 24 columns]

# %%
testSet.columns.values[1] = 'locu_id'
testSet.columns.values[11] = 'foursquare_id'
testSet.head()
# Out:
#          country               locu_id  latitude_x  locality  longitude_x  \
# 0  United States  b48da849c54f904013e2   40.758005  New York   -73.992727
# 1  United States  b48da849c54f904013e2   40.758005  New York   -73.992727
# 2  United States  b48da849c54f904013e2   40.758005  New York   -73.992727
# 3  United States  b48da849c54f904013e2   40.758005  New York   -73.992727
# 4  United States  b48da849c54f904013e2   40.758005  New York   -73.992727
#
#              name_x     phone_x postal_code region street_address_x    ...     \
# 0  panda restaurant  2126950836       10036     NY  570 9th aveast     ...
# 1  panda restaurant  2126950836       10036     NY  570 9th aveast     ...
# 2  panda restaurant  2126950836       10036     NY  570 9th aveast     ...
# 3  panda restaurant  2126950836       10036     NY  570 9th aveast     ...
# 4  panda restaurant  2126950836       10036     NY  570 9th aveast     ...
#
#                    name_y     phone_y   street_address_y  \
# 0  the biggest little bar        None  59 west  46th st.
# 1     tiger bar and grill        None  15 west  43rd st.
# 2        panda restaurant  2126950836    570 9th aveast
# 3        church's chicken  2123159600    705 8th aveast
# 4         brooklyn hummus        None      moving target
#
#                 website_y  lat_diff long_diff phone_diff name_diff  \
# 0                          0.000568  0.011167          0        19
# 1                          0.003524  0.011397          0        16
# 2  http://www.pandarg.com  0.000013  0.000086          1         0
# 3                          0.000670  0.003678          0        16
# 4                          0.001748  0.007494          0        15
#
#    address_diff  web_diff
# 0            12        19
# 1            12        19
# 2             0         5
# 3             3        19
# 4            13        19
#
# [5 rows x 24 columns]

# %%
trainSet._data = trainSet._data.rename_axis(lambda x: x, 0, True)
testSet._data = testSet._data.rename_axis(lambda x: x, 0, True)

# %%
#Set match as 1
match_train['match'] = 1
match_train.head()
# Out:
#                 locu_id             foursquare_id  match
# 0  1dae3a8f02f730c3528d  4b694c01f964a520139e2be3      1
# 1  219c994dcc53f891ec26  506b6162e4b02bda7fc846ee      1
# 2  e06dd73a03f255a877de  4fcb5d2ee4b0928dc1d32f10      1
# 3  cf429074f6b45f0ad183  4c2d2315e116e21e1b1a8e60      1
# 4  be428df89cec53c29e96  43ed7e9ef964a5204e2f1fe3      1

# %%
train = trainSet.merge(match_train, how = "outer", on = ["locu_id", "foursquare_id"])
test = testSet

# %%
train.shape, test.shape
# Out:
# ((16078, 25), (6881, 24))

# %%
#Fill nan with 0 in match column
values = {'match': 0}
train = train.fillna(value = values)

# %%
list(train)
# Out:
# ['country',
#  'locu_id',
#  'latitude_x',
#  'locality',
#  'longitude_x',
#  'name_x',
#  'phone_x',
#  'postal_code',
#  'region',
#  'street_address_x',
#  'website_x',
#  'foursquare_id',
#  'latitude_y',
#  'longitude_y',
#  'name_y',
#  'phone_y',
#  'street_address_y',
#  'website_y',
#  'lat_diff',
#  'long_diff',
#  'phone_diff',
#  'name_diff',
#  'address_diff',
#  'web_diff',
#  'match']

# %%
test.index = pd.RangeIndex(len(test.index))

# %% [markdown]
# ### 5. Train data with Random Forest

# %%
data = train[['lat_diff','long_diff', 'phone_diff', 'name_diff','address_diff','web_diff', 'match']]
data_test = test[['lat_diff','long_diff', 'phone_diff', 'name_diff','address_diff','web_diff']]
#y_train = train[['match']]

# %%
data.shape, data_test.shape
# Out:
# ((16078, 7), (6881, 6))

# %%
data = data.dropna(subset = ['lat_diff','long_diff', 'phone_diff', 'name_diff','address_diff','web_diff'], how='all')
data_test = data_test.dropna(subset = ['lat_diff','long_diff', 'phone_diff', 'name_diff','address_diff','web_diff'], how='all')

# %%
data.shape,data_test.shape
# Out:
# ((16027, 7), (6881, 6))

# %%
X_train = data[['lat_diff','long_diff', 'phone_diff', 'name_diff','address_diff','web_diff']]
y_train = data[['match']]

X_test = data_test[['lat_diff','long_diff', 'phone_diff', 'name_diff','address_diff','web_diff']]

# %%
pd.concat([X_train.dtypes,
           y_train.dtypes,
           X_test.dtypes],axis = 1)
# Out:
#                     0        1        2
# address_diff  float64      NaN    int64
# lat_diff      float64      NaN  float64
# long_diff     float64      NaN  float64
# match             NaN  float64      NaN
# name_diff     float64      NaN    int64
# phone_diff    float64      NaN    int64
# web_diff      float64      NaN    int64

# %%
pd.concat([X_train.apply(lambda x: sum(x.isnull())).rename("num_missing"),
          X_test.apply(lambda x: sum(x.isnull())).rename("num_missing")],axis=1)
# Out:
#               num_missing  num_missing
# lat_diff               13           12
# long_diff              13           12
# phone_diff              0            0
# name_diff               0            0
# address_diff            0            0
# web_diff                0            0

# %%
X_train[X_train['lat_diff'].isnull()]
# Out:
#     lat_diff  long_diff  phone_diff  name_diff  address_diff  web_diff
# 26       NaN        NaN         0.0       16.0          17.0      11.0
# 27       NaN        NaN         0.0       15.0          16.0      27.0
# 28       NaN        NaN         0.0       19.0          12.0      27.0
# 29       NaN        NaN         0.0       15.0          17.0      27.0
# 30       NaN        NaN         0.0       16.0           0.0      27.0
# 31       NaN        NaN         0.0       15.0          17.0      27.0
# 32       NaN        NaN         0.0       17.0          34.0      27.0
# 33       NaN        NaN         0.0       15.0           8.0      27.0
# 34       NaN        NaN         0.0       17.0          17.0      27.0
# 35       NaN        NaN         0.0       18.0          27.0      14.0
# 36       NaN        NaN         0.0       18.0          18.0      15.0
# 37       NaN        NaN         0.0       16.0          14.0      27.0
# 38       NaN        NaN         0.0       17.0          16.0      14.0

# %%
X_test[X_test['lat_diff'].isnull()]
# Out:
#       lat_diff  long_diff  phone_diff  name_diff  address_diff  web_diff
# 1686       NaN        NaN           0          7            15        17
# 1687       NaN        NaN           0         12            13        19
# 1688       NaN        NaN           0         22            13        19
# 1689       NaN        NaN           0          9            11        19
# 1690       NaN        NaN           0         22            14        15
# 1691       NaN        NaN           0         15             5        17
# 1692       NaN        NaN           0         12            15        16
# 1693       NaN        NaN           0         13            13        19
# 1694       NaN        NaN           0         28            16        13
# 1695       NaN        NaN           0          9            14        19
# 1696       NaN        NaN           0         17             7        19
# 1697       NaN        NaN           0         12            14        11

# %%
X_train = X_train.apply(lambda x:x.fillna(x.value_counts().index[0]))
X_test = X_test.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
X_train[['lat_diff']] = pd.to_numeric(X_train.lat_diff)
X_train[['long_diff']] = pd.to_numeric(X_train.long_diff)

# %%
rf = RandomForestClassifier(n_estimators=95)
rf.fit(X_train, y_train)
# Out:
# /Users/zhaoqinwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=95, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print("f1_score of random forest: {:.3f}".format(
      f1_score(y_train, rf.predict(X_train))))
# Out:
# f1_score of random forest: 1.000

# %%
ap_rf = average_precision_score(y_train, rf.predict_proba(X_train)[:, 1])
print("Average precision of random forest: {:.3f}".format(ap_rf))
# Out:
# Average precision of random forest: 1.000

# %%
print("Average recall of random forest: ", recall_score(y_train, rf.predict(X_train)))
# Out:
# Average recall of random forest:  1.0

# %%
y_predict = rf.predict(X_test)

# %%
match = pd.DataFrame({'match': y_predict})

# %%
matches_test = test.join(match)

# %%
matches_test[matches_test['match'] == 1.0]
# Out:
#             country               locu_id  latitude_x  locality  longitude_x  \
# 2     United States  b48da849c54f904013e2   40.758005  New York   -73.992727
# 24    United States  62b24f96cfd688427793   40.760450  New York   -73.995531
# 67    United States  5cf740cd2f459b3adf4a   40.755215  New York   -73.980984
# 81    United States  cf5c0c3850b153c65de0   40.757243  New York   -73.989778
# 122   United States  09f365913e3f95717962   40.758261  New York   -73.993411
# 138   United States  dfbf97a23697bda1f336   40.759079  New York   -73.987968
# 149   United States  b44a5d3c5b07627dc2ad   40.757364  New York   -73.985485
# 184   United States  e34c98f447b1b7dc1d1e   40.756257  New York   -73.985233
# 201   United States  3130f6fd989210a73c9a   40.758918  New York   -73.988773
# 222   United States  95ad783fd1c65bb8fdbf   40.721025  New York   -73.982903
# 248   United States  be74338f204c673792a9   40.722543  New York   -73.988607
# 249   United States  be09c05ea69bd534bc15   40.730826  New York   -73.983017
# 280   United States  1c5aef8c4c24e7301010   40.717092  New York   -73.990020
# 287   United States  919f4e7970c60246981a   40.723030  New York   -73.988940
# 305   United States  cbfd92b823c9fbc4b4a6   40.719449  New York   -73.988768
# 323   United States  47abb39cdfc2e8d9cc51   40.718583  New York   -73.990042
# 333   United States  182875365fa3340e4cfc   40.721779  New York   -73.990218
# 362   United States  6cf89af641496bdb754a   40.715138  New York   -73.993425
# 431   United States  b01d81fb2b9f229da96e   40.745152  New York   -73.975494
# 486   United States  469fb2c083a6698e151b   40.726631  New York   -73.989873
# 505   United States  e6699064410879503ab1   40.726159  New York   -73.991429
# 574   United States  f2a8ae1ac18283a9930c   40.733878  New York   -73.988125
# 648   United States  be4ea0b3e9a4d332b473   40.737901  New York   -73.987822
# 667   United States  d1e4f460421b50454e6d   40.733787  New York   -73.993035
# 754   United States  7921631d41c36f8528b1   40.736821  New York   -73.987255
# 804   United States  f78dd98d3e8b7df68c9b   40.737283  New York   -73.990908
# 830   United States  a7204b0cdc217e8809cf   40.737588  New York   -73.991144
# 915   United States  29e379eb81897ebbc263   40.729373  New York   -73.989251
# 943   United States  5a34084ad4035d349a75   40.736400  New York   -73.988892
# 972   United States  4a26aca4089d7cc99963   40.802322  New York   -73.944954
# ...             ...                   ...         ...       ...          ...
# 6651  United States  1fb411f1d552e2e5bb7f   40.753993  New York   -73.975774
# 6656  United States  8bb064a614c4866beaea   40.751879  New York   -73.974106
# 6663  United States  e89044fc0d4a71ed176b   40.790393  New York   -73.947466
# 6677  United States  03cfd8615163b97ea5c1   40.798579  New York   -73.941202
# 6685  United States  9305ca4d816868b3f861   40.787723  New York   -73.943580
# 6689  United States  6386cbb1376e266252ee   40.791687  New York   -73.944039
# 6701  United States  4eb12f6a725e7cf7c8e6   40.772891  New York   -73.952517
# 6704  United States  fdc46e327356da88bd44   40.778809  New York   -73.955762
# 6710  United States  7351366c2b554873eb7d   40.777875  New York   -73.956922
# 6728  United States  36b176294d9bb77d22ab   40.775697  New York   -73.953537
# 6737  United States  6143d53e474b953ae451   40.775142  New York   -73.956644
# 6754  United States  0944648c147bf96780ff   40.845151  New York   -73.938017
# 6757  United States  044a45cdc9bac30cb07a   40.851387  New York   -73.939533
# 6771  United States  71b7200a54c9f1e92780   40.851421  New York   -73.928286
# 6792  United States  278dd7a1fa00e9187aa4   40.855324  New York   -73.937240
# 6793  United States  cdca6ce02b5fa7d0354b   40.748071  New York   -73.985063
# 6794  United States  51e22ba807ddc2a59a21   40.690304  New York   -73.924308
# 6796  United States  c58156618c687f826691   40.704544  New York   -74.010913
# 6797  United States  f1a683f11d1243992f35   40.704988  New York   -74.009785
# 6832  United States  4049481bdbb7ef04e899   40.769271  New York   -73.954948
# 6845  United States  2d2408d2da8bf37862da   40.766957  New York   -73.964660
# 6855  United States  85c01bb5c538231cd2c5   40.769502  New York   -73.960555
# 6859  United States  302dfee85174a22db0fe   40.811314  New York   -73.952280
# 6864  United States  78595981d7a444f172a4   40.784321  New York   -73.973966
# 6870  United States  78c1f0e5a627c06f1de7   40.787930  New York   -73.977486
# 6875  United States  433ac74d7040c806975f   40.721543  New York   -73.980415
# 6877  United States  616c752e4bfca0197a95   40.753129  New York   -73.974951
# 6878  United States  c73b4e365cbbd04f4aa6   40.660479  New York   -73.930612
# 6879  United States  2b668062260de1d07fb1   40.759304  New York   -73.918789
# 6880  United States  fb96cd922554c157d3a1   40.705565  New York   -74.008019
#
#                                                  name_x     phone_x  \
# 2                                      panda restaurant  2126950836
# 24                      happy family chinese restaurant  2126956035
# 67                                       jewel of india  2128695544
# 81                                  south philly steaks
# 122                                         theater row
# 138                      frankie & johnnie's steakhouse  2129979494
# 149                                    the lodge @ 1515  2128466633
# 184                                     brooklyn hummus
# 201                                    church's chicken  2123159600
# 222                                 el maguey y la tuna  2124733919
# 248                          brbg at the thompson hotel  2124605300
# 249                                        the delancey  2122549920
# 280                                              subway  2127772372
# 287                                national underground  2124750611
# 305                                            mehanata  2126250981
# 323                                           pop karma  9176757450
# 333                                  le chateau bow wow
# 362                      super taste chinese restaurant  6462830999
# 431                                  french restaurants
# 486                       venue #12: 4th street theatre
# 505   save the sound by auduban society at the bower...
# 574          raymour & flanigan furniture | 14th street  6466520372
# 648                                              chango  2124771500
# 667                                        the grey dog  2124144739
# 754                           paul & jimmy's restaurant  2124759540
# 804                               chop't creative salad  6463365527
# 830                                          the square
# 915                                          cafe fuego  2126777300
# 943                                          trevi deli  2124734493
# 972                    private brazillian party. dig it
# ...                                                 ...         ...
# 6651                                     hatsuhana park  2126613400
# 6656                        five guys burgers and fries  6467835060
# 6663                                  sofrito's burgers
# 6677                                     domino's pizza  2128311024
# 6685                 star gourmet deli - 2000 n.y. deli  2124269591
# 6689                             kentucky fried chicken  2124230599
# 6701                                   pizza restaurant
# 6704                        the luxurey sweet penthouse
# 6710                                           lechurro  6466495253
# 6728                                 jack russell's pub  2124722800
# 6737                        taste restaurant & wine bar  2127179798
# 6754                                  da heights lounge
# 6757                                         sushi yu 2  2127818833
# 6771                             grandma's kosher pizza  2129274895
# 6792                                    next door - nyc  2125432111
# 6793                             chipotle mexican grill  2126950412
# 6794                                     dunkin' donuts  7184539880
# 6796                                     luke's lobster  2127471700
# 6797                                           yorganic  2129689700
# 6832                                         rectangles  2127447470
# 6845                                  ebony escorts nyc  9173794224
# 6855                                          the couch
# 6859                                   kilimanjaro deli
# 6864                                       cafe blossom  2128752600
# 6870               kasbah bbq & grill kosher restaurant  2124961500
# 6875                                       chez bergman
# 6877                             kenny babbo's escalade
# 6878                       cafe soul jamaican resturant  7187739353
# 6879                                   great eatery inc  7187215000
# 6880                                       wall & water  2126991700
#
#      postal_code region                    street_address_x  ...    \
# 2          10036     NY                     570 9th aveast   ...
# 24         10036     NY                   500 west 43rd st.  ...
# 67         10036     NY                   15 west  44th st.  ...
# 81         10036     NY                                      ...
# 122        10036     NY                   410 west 42nd st.  ...
# 138        10036     NY                   269 west 45th st.  ...
# 149        10036     NY                       1515 broadway  ...
# 184        10036     NY                       moving target  ...
# 201        10036     NY                     705 8th aveast   ...
# 222        10002     NY                321 east houston st.  ...
# 248        10002     NY                       190 allen st.  ...
# 249        10002     NY                    168 delancey st.  ...
# 280        10002     NY                       334 grand st.  ...
# 287        10002     NY               159 east  houston st.  ...
# 305        10002     NY                      113 ludlow st.  ...
# 323        10002     NY                      95 orchard st.  ...
# 333        10002     NY                      57 stanton st.  ...
# 362        10002     NY                     26 eldridge st.  ...
# 431        10003     NY  34 2nd aveast , new york, ny 10003  ...
# 486        10003     NY                     83 east 4th st.  ...
# 505        10003     NY                                      ...
# 574        10003     NY                  133 east  14th st.  ...
# 648        10003     NY              239 park aveast  south  ...
# 667        10003     NY                   90 university pl.  ...
# 754        10003     NY                   123 east 18th st.  ...
# 804        10003     NY                   24 east  17th st.  ...
# 830        10003     NY                   120 east 15th st.  ...
# 915        10003     NY                   9 saint marks pl.  ...
# 943        10003     NY                48 union square east  ...
# 972        10035     NY                                      ...
# ...          ...    ...                                 ...  ...
# 6651       10017     NY                    237 park aveast   ...
# 6656       10017     NY                     690 3rd aveast   ...
# 6663       10029     NY              1634 lexington aveast   ...
# 6677       10029     NY                  153 east 116th st.  ...
# 6685       10029     NY                    2000 2nd aveast   ...
# 6689       10029     NY                    1922 3rd aveast   ...
# 6701       10028     NY                    1526 1st aveast   ...
# 6704       10028     NY              1264 lexington aveast   ...
# 6710       10028     NY              1236 lexington aveast   ...
# 6728       10028     NY                    1591 2nd aveast   ...
# 6737       10028     NY                  1413 third aveast   ...
# 6754       10033     NY                                      ...
# 6757       10033     NY                  827 west 181st st.  ...
# 6771       10033     NY              2551 amsterdam aveast   ...
# 6792       10033     NY       811 west 187<sup>th</sup> st.  ...
# 6793       10118     NY                  350 5th aveast  #4  ...
# 6794       11221     NY                       1285 broadway  ...
# 6796       10004     NY                26 south william st.  ...
# 6797       10004     NY                    3 hanover square  ...
# 6832       10021     NY                    1431 1st aveast   ...
# 6845       10021     NY                                      ...
# 6855       10021     NY                                      ...
# 6859       10027     NY                                      ...
# 6864       10024     NY                466 columbus aveast   ...
# 6870       10024     NY                   251 west 85th st.  ...
# 6875       11211     NY                           63 n. 3rd  ...
# 6877       10170     NY                                      ...
# 6878       11203     NY                     875 rutland rd.  ...
# 6879       11103     NY                  31-78 steinway st.  ...
# 6880       10005     NY                         75 wall st.  ...
#
#          phone_y                    street_address_y  \
# 2     2126950836                     570 9th aveast
# 24    2126956035                  500 west  43rd st.
# 67    2128695544                   15 west  44th st.
# 81          None
# 122         None                   410 west 42nd st.
# 138   2129979494                  269 west  45th st.
# 149   2128466633                       1515 broadway
# 184         None                       moving target
# 201   2123159600                     705 8th aveast
# 222   2124733744               321 east  houston st.
# 248   2124605300                       190 allen st.
# 249         None
# 280   9176919839                       334 grand st.
# 287   2124750611               159 east  houston st.
# 305   2126250981                      113 ludlow st.
# 323   9176757450                      95 orchard st.
# 333         None                      57 stanton st.
# 362   6462830999                     26 eldridge st.
# 431         None  34 2nd aveast , new york, ny 10003
# 486         None                     83 east 4th st.
# 505         None
# 574   6466520372                  133 east  14th st.
# 648   2124771500                 239 park aveast  s.
# 667   2124144739                   90 university pl.
# 754   2124759540                  123 east  18th st.
# 804   6463365527                   24 east  17th st.
# 830         None
# 915   2126777300                   9 saint marks pl.
# 943   2124734493                  48 union sq. east
# 972         None
# ...          ...                                 ...
# 6651  2126613400                    237 park aveast
# 6656  6467835060                     690 3rd aveast
# 6663        None              1634 lexington aveast
# 6677  2128311024                 153 east  116th st.
# 6685  2124269591                    2000 2nd aveast
# 6689  2124230599                    1922 3rd aveast
# 6701        None                    1526 1st aveast
# 6704        None              1264 lexington aveast
# 6710  6466495253              1236 lexington aveast
# 6728  2124722800                    1591 2nd aveast
# 6737  2127179798                    1411 3rd aveast
# 6754        None
# 6757  2127818833                 827 west  181st st.
# 6771  2129274895              2551 amsterdam aveast
# 6792  2125432111                 813 west  187th st.
# 6793  2126950412         350 fifth aveast  / ste 4 5
# 6794  7184539880                       1285 broadway
# 6796  2127471700                   26 s. william st.
# 6797  2129689700                       3 hanover sq.
# 6832  2127447470                    1431 1st aveast
# 6845  9173794224
# 6855        None
# 6859        None
# 6864  2128752600                466 columbus aveast
# 6870  2124961500                  251 west  85th st.
# 6875        None                           63 n. 3rd
# 6877        None
# 6878        None                     875 rutland rd.
# 6879  7187215000                  31-78 steinway st.
# 6880                                     andaz hotel
#
#                                               website_y  lat_diff long_diff  \
# 2                                http://www.pandarg.com  0.000013  0.000086
# 24                                                       0.000661  0.000280
# 67                           http://jewelofindianyc.com  0.000000  0.000000
# 81                                                       0.000000  0.000000
# 122                                                      0.000000  0.000000
# 138                   http://www.frankieandjohnnies.com  0.000100  0.000186
# 149                                                      0.000000  0.000000
# 184                                                      0.000000  0.000000
# 201                                                      0.000243  0.000276
# 222                        http://elmagueylatunanyc.com  0.000237  0.000041
# 248                                                      0.000000  0.000000
# 249                                                      0.000000  0.000000
# 280                                                      0.000090  0.000030
# 287   http://www.thenationalunderground.com/newyorkv...  0.000000  0.000000
# 305                                 http://mehanata.com  0.000027  0.000058
# 323                             http://www.popkarma.com  0.000000  0.000000
# 333                                                      0.000000  0.000000
# 362                                                      0.000096  0.000095
# 431                                                      0.000000  0.000000
# 486                                                      0.000000  0.000000
# 505                                                      0.000000  0.000000
# 574                      http://www.raymourflanigan.com  0.000000  0.000000
# 648                                                      0.000821  0.000351
# 667                           http://www.thegreydog.com  0.000000  0.000000
# 754                                                      0.000076  0.000209
# 804                           http://www.choptsalad.com  0.000000  0.000000
# 830                                                      0.000000  0.000000
# 915                                                      0.000000  0.000000
# 943                                                      0.000181  0.000111
# 972                                                      0.000000  0.000000
# ...                                                 ...       ...       ...
# 6651                 http://www.hatsuhanaparkavenyc.com  0.000000  0.000000
# 6656                            http://www.fiveguys.com  0.000198  0.000037
# 6663                                                     0.000000  0.000000
# 6677                             http://www.dominos.com  0.000172  0.000079
# 6685                                                     0.000000  0.000000
# 6689                                                     0.000000  0.000000
# 6701                                                     0.000000  0.000000
# 6704                                                     0.000000  0.000000
# 6710                                http://lechurro.com  0.000042  0.000198
# 6728                     http://www.jackrussellsnyc.com  0.000062  0.000016
# 6737           http://www.elizabar.com/taste/taste.html  0.000062  0.000069
# 6754                                                     0.000000  0.000000
# 6757                                                     0.000287  0.000079
# 6771                                                     0.000093  0.000259
# 6792                                                     0.000131  0.000073
# 6793                            http://www.chipotle.com  0.000331  0.000100
# 6794                        http://www.dunkindonuts.com  0.000000  0.000000
# 6796                   http://www.lukeslobster.com/fidi  0.000271  0.000551
# 6797                                                     0.000206  0.000300
# 6832                                                     0.000000  0.000000
# 6845                                                     0.000000  0.000000
# 6855                                                     0.000000  0.000000
# 6859                                                     0.000000  0.000000
# 6864                              http://blossomnyc.com  0.000095  0.000155
# 6870                          http://www.delikasbah.com  0.000121  0.000045
# 6875                                                     0.000000  0.000000
# 6877                                                     0.000000  0.000000
# 6878                                                     0.000000  0.000000
# 6879                                                     0.000000  0.000000
# 6880                                                     0.000322  0.000015
#
#      phone_diff name_diff address_diff  web_diff  match
# 2             1         0            0         5    1.0
# 24            1         0            1        34    1.0
# 67            1         0            0         0    1.0
# 81            0         0            0         0    1.0
# 122           0         0            0         0    1.0
# 138           1         3            1         1    1.0
# 149           1         0            0         0    1.0
# 184           0         0            0         0    1.0
# 201           1         0            0        23    1.0
# 222           0         0            1         8    1.0
# 248           1         0            0        53    1.0
# 249           0         0           16        26    1.0
# 280           0         0            0        57    1.0
# 287           1         0            0         0    1.0
# 305           1        14            0         5    1.0
# 323           1         0            0         0    1.0
# 333           0         0            0         0    1.0
# 362           1        19            0        25    1.0
# 431           0         0            0         0    1.0
# 486           0         0            0         0    1.0
# 505           0         0            0         0    1.0
# 574           1         0            0         0    1.0
# 648           1         0            4         0    1.0
# 667           1         0            0         0    1.0
# 754           1        11            1        24    1.0
# 804           1         0            0         0    1.0
# 830           0         0           17         0    1.0
# 915           1         0            0        21    1.0
# 943           1         0            5         0    1.0
# 972           0         0            0         0    1.0
# ...         ...       ...          ...       ...    ...
# 6651          1         0            0         0    1.0
# 6656          1        18            0         1    1.0
# 6663          0         0            0         0    1.0
# 6677          1         0            1       105    1.0
# 6685          1         0            0         0    1.0
# 6689          1         0            0         0    1.0
# 6701          0         0            0         0    1.0
# 6704          0         0            0         0    1.0
# 6710          1         0            0         1    1.0
# 6728          1         4            0        24    1.0
# 6737          1         0            4        17    1.0
# 6754          0         0            0         0    1.0
# 6757          1         2            1        25    1.0
# 6771          1         7            0         0    1.0
# 6792          1         6           13        22    1.0
# 6793          1         0           11         1    1.0
# 6794          1         0            0         0    1.0
# 6796          1         5            4         4    1.0
# 6797          1         0            4        23    1.0
# 6832          1         0            0        36    1.0
# 6845          1         0            0         0    1.0
# 6855          0         0            0         0    1.0
# 6859          0         0            0         0    1.0
# 6864          1         1            0        16    1.0
# 6870          1        23            1         1    1.0
# 6875          0         0            0         0    1.0
# 6877          0         0            0         0    1.0
# 6878          0         0            0         0    1.0
# 6879          1         0            0         0    1.0
# 6880          0         0           10        29    1.0
#
# [205 rows x 25 columns]

# %%
locu_id = matches_test[matches_test['match'] == 1.0].locu_id
foursquare_id = matches_test[matches_test['match'] == 1.0].foursquare_id
pd.concat([locu_id,foursquare_id], axis = 1)
# Out:
#                    locu_id             foursquare_id
# 2     b48da849c54f904013e2  4de5a887d4c09fc98b6e0498
# 24    62b24f96cfd688427793  4b8479faf964a520c73731e3
# 67    5cf740cd2f459b3adf4a  4a6f5aeff964a520f7d51fe3
# 81    cf5c0c3850b153c65de0  4f132b78e4b0725fed9a3c28
# 122   09f365913e3f95717962  4a3d766ff964a52051a21fe3
# 138   dfbf97a23697bda1f336  4b7b37b9f964a520a4582fe3
# 149   b44a5d3c5b07627dc2ad  4ad8b68cf964a520e71321e3
# 184   e34c98f447b1b7dc1d1e  4c49b2a41b430f47de20e5c3
# 201   3130f6fd989210a73c9a  4b512af9f964a520a94527e3
# 222   95ad783fd1c65bb8fdbf  459f6987f964a520c0401fe3
# 248   be74338f204c673792a9  519b78372fc6182159f7eb0d
# 249   be09c05ea69bd534bc15  50837291e4b0e99d0bfd7a30
# 280   1c5aef8c4c24e7301010  4b60f5ccf964a5209c032ae3
# 287   919f4e7970c60246981a  49cc222df964a5204a591fe3
# 305   cbfd92b823c9fbc4b4a6  4aaa663bf964a520d65520e3
# 323   47abb39cdfc2e8d9cc51  4fff3023e4b04497d9436ca4
# 333   182875365fa3340e4cfc  4bca85b1511f95211e15b0c7
# 362   6cf89af641496bdb754a  49e8ee2ef964a520af651fe3
# 431   b01d81fb2b9f229da96e  4f97435fe4b087cfab007dc8
# 486   469fb2c083a6698e151b  4c265b13db5195215f622c3a
# 505   e6699064410879503ab1  50776130e4b0602b6168ab41
# 574   f2a8ae1ac18283a9930c  4b9990d1f964a520108435e3
# 648   be4ea0b3e9a4d332b473  3fd66200f964a520aee41ee3
# 667   d1e4f460421b50454e6d  49b5889bf964a520fa521fe3
# 754   7921631d41c36f8528b1  4ae77a1bf964a520b6ab21e3
# 804   f78dd98d3e8b7df68c9b  49be9addf964a520c4541fe3
# 830   a7204b0cdc217e8809cf  5013520ae4b0dbe157f818d1
# 915   29e379eb81897ebbc263  44d5bb1cf964a52056361fe3
# 943   5a34084ad4035d349a75  4aafbe03f964a520996420e3
# 972   4a26aca4089d7cc99963  4fd4368ce4b0a8f5716e88e3
# ...                    ...                       ...
# 6651  1fb411f1d552e2e5bb7f  4ac4cc5df964a520059f20e3
# 6656  8bb064a614c4866beaea  4b44c9b4f964a52030fc25e3
# 6663  e89044fc0d4a71ed176b  4dce0f2c45ddbe15f88064d2
# 6677  03cfd8615163b97ea5c1  4c0ab529a1b32d7fd8d599f0
# 6685  9305ca4d816868b3f861  4b988004f964a520cc4435e3
# 6689  6386cbb1376e266252ee  4c62d76879d1e21e5b10d715
# 6701  4eb12f6a725e7cf7c8e6  4fdb54e1e4b037067e2778d2
# 6704  fdc46e327356da88bd44  4bdbb935c79cc928264a84e9
# 6710  7351366c2b554873eb7d  5082f364e4b00b2c405bf3bb
# 6728  36b176294d9bb77d22ab  45fe3baef964a52082441fe3
# 6737  6143d53e474b953ae451  4e4e4ba0bd4101d0d7a7125a
# 6754  0944648c147bf96780ff  500c6444e4b0e68938acc1d9
# 6757  044a45cdc9bac30cb07a  4a4a642cf964a520bdab1fe3
# 6771  71b7200a54c9f1e92780  4c24cfeeb7b8a593df0f3de8
# 6792  278dd7a1fa00e9187aa4  4a50e74cf964a5203db01fe3
# 6793  cdca6ce02b5fa7d0354b  4aa44e08f964a5204f4620e3
# 6794  51e22ba807ddc2a59a21  4bee77aae8c3c92821b79892
# 6796  c58156618c687f826691  4db739d841592dd82ee2b3dd
# 6797  f1a683f11d1243992f35  4a6e3e6bf964a5204dd41fe3
# 6832  4049481bdbb7ef04e899  4a5910c8f964a52094b81fe3
# 6845  2d2408d2da8bf37862da  5127d927b0ed88901a3d025b
# 6855  85c01bb5c538231cd2c5  50836734e4b0e99d0bf8152c
# 6859  302dfee85174a22db0fe  4c663080c2ead13a3340b380
# 6864  78595981d7a444f172a4  49f4f7ebf964a5207c6b1fe3
# 6870  78c1f0e5a627c06f1de7  4b01f66df964a520db4622e3
# 6875  433ac74d7040c806975f  4fc05a30e4b021b6df6f6a45
# 6877  616c752e4bfca0197a95  505e3f84e4b08dae9b7f9f6a
# 6878  c73b4e365cbbd04f4aa6  4e55b257e4cd779e8339f0ef
# 6879  2b668062260de1d07fb1  4db17de393a061576855ad2e
# 6880  fb96cd922554c157d3a1  4b4b74eaf964a520709c26e3
#
# [205 rows x 2 columns]

# %%
pd.concat([locu_id,foursquare_id], axis = 1).to_csv('matches_test.csv', index=False,header=True)

# %%
rf.feature_importances_
plt.barh(range(6), rf.feature_importances_)
plt.yticks(range(6), ['lat_diff','long_diff', 'phone_diff', 'name_diff','address_diff','web_diff'])
# Out:
# ([<matplotlib.axis.YTick at 0x1a15ef1438>,
#   <matplotlib.axis.YTick at 0x1a15ee77b8>,
#   <matplotlib.axis.YTick at 0x1a15f31128>,
#   <matplotlib.axis.YTick at 0x1a16750588>,
#   <matplotlib.axis.YTick at 0x1a167554e0>,
#   <matplotlib.axis.YTick at 0x1a16757978>],
#  <a list of 6 Text yticklabel objects>)
